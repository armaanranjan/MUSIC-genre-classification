# %% [markdown]
# <a href="https://colab.research.google.com/github/armaanranjan/MUSIC-genre-classification/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa.display

# %%
music_data = pd.read_csv('/file.csv')
music_data.head(5)
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# 1              2039.036516           213843.755497  ...   55.356403
# 2              1747.702312            76254.192257  ...   40.598766
# 3              1596.412872           166441.494769  ...   44.427753
# 4              1748.172116            88445.209036  ...   86.099236
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -1.690215   36.524071    -0.408979   41.597103    -2.303523   55.062923
# 1    -0.731125   60.314529     0.295073   48.120598    -0.283518   51.106190
# 2    -7.729093   47.639427    -1.816407   52.382141    -3.439720   46.639660
# 3    -3.319597   50.206673     0.636965   37.319130    -0.619121   37.259739
# 4    -5.454034   75.269707    -0.916874   53.613918    -4.404827   62.910812
#
#    mfcc20_mean  mfcc20_var  label
# 0     1.221291   46.936035  blues
# 1     0.531217   45.786282  blues
# 2    -2.231258   30.573025  blues
# 3    -3.407448   31.949339  blues
# 4   -11.703234   55.195160  blues
#
# [5 rows x 60 columns]

# %%
music_data['label'].value_counts()
# Out:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: count, dtype: int64

# %%
import numpy as np
import seaborn as sns
# Computing the Correlation Matrix
spike_cols = [col for col in music_data.columns if 'mean' in col]

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 11));

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(music_data[spike_cols].corr(), cmap='YlGn')

plt.title('Heatmap for MEAN variables', fontsize = 20)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5]),
#  [Text(0, 0.5, 'chroma_stft_mean'),
#   Text(0, 1.5, 'rms_mean'),
#   Text(0, 2.5, 'spectral_centroid_mean'),
#   Text(0, 3.5, 'spectral_bandwidth_mean'),
#   Text(0, 4.5, 'rolloff_mean'),
#   Text(0, 5.5, 'zero_crossing_rate_mean'),
#   Text(0, 6.5, 'harmony_mean'),
#   Text(0, 7.5, 'perceptr_mean'),
#   Text(0, 8.5, 'mfcc1_mean'),
#   Text(0, 9.5, 'mfcc2_mean'),
#   Text(0, 10.5, 'mfcc3_mean'),
#   Text(0, 11.5, 'mfcc4_mean'),
#   Text(0, 12.5, 'mfcc5_mean'),
#   Text(0, 13.5, 'mfcc6_mean'),
#   Text(0, 14.5, 'mfcc7_mean'),
#   Text(0, 15.5, 'mfcc8_mean'),
#   Text(0, 16.5, 'mfcc9_mean'),
#   Text(0, 17.5, 'mfcc10_mean'),
#   Text(0, 18.5, 'mfcc11_mean'),
#   Text(0, 19.5, 'mfcc12_mean'),
#   Text(0, 20.5, 'mfcc13_mean'),
#   Text(0, 21.5, 'mfcc14_mean'),
#   Text(0, 22.5, 'mfcc15_mean'),
#   Text(0, 23.5, 'mfcc16_mean'),
#   Text(0, 24.5, 'mfcc17_mean'),
#   Text(0, 25.5, 'mfcc18_mean'),
#   Text(0, 26.5, 'mfcc19_mean'),
#   Text(0, 27.5, 'mfcc20_mean')])

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
music_data['label'] = label_encoder.fit_transform(music_data['label'])

# %%
X = music_data.drop(['label','filename'],axis=1)
y = music_data['label']

# %%
cols = X.columns
minmax = preprocessing.MinMaxScaler()
np_scaled = minmax.fit_transform(X)

# new data frame with the new scaled data.
X = pd.DataFrame(np_scaled, columns = cols)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=111)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 58), (300, 58), (700,), (300,))

# %%
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import catboost as cb
from xgboost import XGBClassifier

rf = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0)
cbc = cb.CatBoostClassifier(verbose=0, eval_metric='Accuracy', loss_function='MultiClass')
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)

for clf in (rf, cbc, xgb):
    clf.fit(X_train, y_train)
    preds = clf.predict(X_test)
    print(clf.__class__.__name__,accuracy_score(y_test, preds))
# Out:
# RandomForestClassifier 0.78
# CatBoostClassifier 0.8333333333333334
# XGBClassifier 0.7833333333333333

# %%
import tensorflow.keras as keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *

model = Sequential()

model.add(Flatten(input_shape=(58,)))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 58)                0
#
#  dense (Dense)               (None, 256)               15104
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 50314 (196.54 KB)
# Trainable params: 49802 (194.54 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %%
# compile the model
adam = keras.optimizers.Adam(lr=1e-4)
model.compile(optimizer=adam,
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

hist = model.fit(X_train, y_train,
                 validation_data = (X_test,y_test),
                 epochs = 100,
                 batch_size = 32)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 22/22 [==============================] - 3s 17ms/step - loss: 1.9021 - accuracy: 0.3514 - val_loss: 2.2012 - val_accuracy: 0.0800
# Epoch 2/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.2723 - accuracy: 0.5543 - val_loss: 2.1524 - val_accuracy: 0.0800
# Epoch 3/100
# 22/22 [==============================] - 0s 6ms/step - loss: 1.0423 - accuracy: 0.6571 - val_loss: 2.0575 - val_accuracy: 0.1300
# Epoch 4/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.8904 - accuracy: 0.6971 - val_loss: 1.9728 - val_accuracy: 0.2267
# Epoch 5/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8021 - accuracy: 0.7257 - val_loss: 1.8729 - val_accuracy: 0.4033
# Epoch 6/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.7121 - accuracy: 0.7571 - val_loss: 1.8058 - val_accuracy: 0.4300
# Epoch 7/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.7017 - accuracy: 0.7629 - val_loss: 1.7112 - val_accuracy: 0.5433
# Epoch 8/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6418 - accuracy: 0.7714 - val_loss: 1.6031 - val_accuracy: 0.6267
# Epoch 9/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5851 - accuracy: 0.8029 - val_loss: 1.5064 - val_accuracy: 0.6567
# Epoch 10/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5633 - accuracy: 0.8129 - val_loss: 1.4439 - val_accuracy: 0.6800
# Epoch 11/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5269 - accuracy: 0.8171 - val_loss: 1.3479 - val_accuracy: 0.7133
# Epoch 12/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.4710 - accuracy: 0.8471 - val_loss: 1.2652 - val_accuracy: 0.7033
# Epoch 13/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4478 - accuracy: 0.8400 - val_loss: 1.1512 - val_accuracy: 0.7433
# Epoch 14/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4288 - accuracy: 0.8443 - val_loss: 1.1100 - val_accuracy: 0.7533
# Epoch 15/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.4334 - accuracy: 0.8457 - val_loss: 1.0178 - val_accuracy: 0.7167
# Epoch 16/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.4089 - accuracy: 0.8686 - val_loss: 0.9562 - val_accuracy: 0.7700
# Epoch 17/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3818 - accuracy: 0.8629 - val_loss: 0.8864 - val_accuracy: 0.7633
# Epoch 18/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3762 - accuracy: 0.8643 - val_loss: 0.8708 - val_accuracy: 0.7433
# Epoch 19/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3445 - accuracy: 0.8900 - val_loss: 0.8022 - val_accuracy: 0.7567
# Epoch 20/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2960 - accuracy: 0.9157 - val_loss: 0.7826 - val_accuracy: 0.7433
# Epoch 21/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3158 - accuracy: 0.8986 - val_loss: 0.8464 - val_accuracy: 0.7200
# Epoch 22/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2935 - accuracy: 0.8957 - val_loss: 0.7995 - val_accuracy: 0.7600
# Epoch 23/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2904 - accuracy: 0.9086 - val_loss: 0.7186 - val_accuracy: 0.7733
# Epoch 24/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.9129 - val_loss: 0.7625 - val_accuracy: 0.7333
# Epoch 25/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2617 - accuracy: 0.9100 - val_loss: 0.7879 - val_accuracy: 0.7400
# Epoch 26/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2401 - accuracy: 0.9271 - val_loss: 0.7256 - val_accuracy: 0.7567
# Epoch 27/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2530 - accuracy: 0.9171 - val_loss: 0.7236 - val_accuracy: 0.7500
# Epoch 28/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2451 - accuracy: 0.9243 - val_loss: 0.7485 - val_accuracy: 0.7633
# Epoch 29/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2047 - accuracy: 0.9371 - val_loss: 0.8092 - val_accuracy: 0.7567
# Epoch 30/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1860 - accuracy: 0.9400 - val_loss: 0.8010 - val_accuracy: 0.7833
# Epoch 31/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1954 - accuracy: 0.9357 - val_loss: 0.8459 - val_accuracy: 0.7333
# Epoch 32/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2003 - accuracy: 0.9386 - val_loss: 0.7668 - val_accuracy: 0.7533
# Epoch 33/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1599 - accuracy: 0.9557 - val_loss: 0.8688 - val_accuracy: 0.7433
# Epoch 34/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1688 - accuracy: 0.9514 - val_loss: 0.8383 - val_accuracy: 0.7567
# Epoch 35/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1601 - accuracy: 0.9586 - val_loss: 0.8490 - val_accuracy: 0.7300
# Epoch 36/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1618 - accuracy: 0.9557 - val_loss: 0.8876 - val_accuracy: 0.7467
# Epoch 37/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1611 - accuracy: 0.9486 - val_loss: 0.9217 - val_accuracy: 0.7500
# Epoch 38/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1835 - accuracy: 0.9386 - val_loss: 0.8814 - val_accuracy: 0.7500
# Epoch 39/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1719 - accuracy: 0.9557 - val_loss: 0.9862 - val_accuracy: 0.7300
# Epoch 40/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1397 - accuracy: 0.9700 - val_loss: 0.8802 - val_accuracy: 0.7500
# Epoch 41/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1485 - accuracy: 0.9571 - val_loss: 1.0984 - val_accuracy: 0.7100
# Epoch 42/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1504 - accuracy: 0.9543 - val_loss: 1.0791 - val_accuracy: 0.6767
# Epoch 43/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1790 - accuracy: 0.9400 - val_loss: 0.8799 - val_accuracy: 0.7433
# Epoch 44/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1617 - accuracy: 0.9529 - val_loss: 0.8914 - val_accuracy: 0.7500
# Epoch 45/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1313 - accuracy: 0.9657 - val_loss: 0.9170 - val_accuracy: 0.7667
# Epoch 46/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1455 - accuracy: 0.9486 - val_loss: 0.8511 - val_accuracy: 0.7933
# Epoch 47/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1311 - accuracy: 0.9614 - val_loss: 1.1408 - val_accuracy: 0.7433
# Epoch 48/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1461 - accuracy: 0.9643 - val_loss: 0.8321 - val_accuracy: 0.7800
# Epoch 49/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1265 - accuracy: 0.9600 - val_loss: 0.9829 - val_accuracy: 0.7467
# Epoch 50/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1057 - accuracy: 0.9743 - val_loss: 0.8565 - val_accuracy: 0.7800
# Epoch 51/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1219 - accuracy: 0.9600 - val_loss: 0.9533 - val_accuracy: 0.7633
# Epoch 52/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1236 - accuracy: 0.9571 - val_loss: 0.8903 - val_accuracy: 0.7533
# Epoch 53/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1057 - accuracy: 0.9686 - val_loss: 1.0070 - val_accuracy: 0.7333
# Epoch 54/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1178 - accuracy: 0.9671 - val_loss: 1.0109 - val_accuracy: 0.7467
# Epoch 55/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1010 - accuracy: 0.9657 - val_loss: 1.1040 - val_accuracy: 0.7467
# Epoch 56/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0840 - accuracy: 0.9771 - val_loss: 1.0059 - val_accuracy: 0.7533
# Epoch 57/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0801 - accuracy: 0.9786 - val_loss: 0.9515 - val_accuracy: 0.7567
# Epoch 58/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1141 - accuracy: 0.9657 - val_loss: 0.9858 - val_accuracy: 0.7567
# Epoch 59/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1129 - accuracy: 0.9643 - val_loss: 1.0996 - val_accuracy: 0.7400
# Epoch 60/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0901 - accuracy: 0.9743 - val_loss: 1.0372 - val_accuracy: 0.7333
# Epoch 61/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1073 - accuracy: 0.9671 - val_loss: 1.1140 - val_accuracy: 0.7300
# Epoch 62/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1083 - accuracy: 0.9629 - val_loss: 0.9613 - val_accuracy: 0.7600
# Epoch 63/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1391 - accuracy: 0.9500 - val_loss: 1.1392 - val_accuracy: 0.7167
# Epoch 64/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1172 - accuracy: 0.9657 - val_loss: 1.2308 - val_accuracy: 0.7333
# Epoch 65/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0966 - accuracy: 0.9671 - val_loss: 1.2030 - val_accuracy: 0.7633
# Epoch 66/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0973 - accuracy: 0.9757 - val_loss: 1.1381 - val_accuracy: 0.7400
# Epoch 67/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0996 - accuracy: 0.9714 - val_loss: 1.2080 - val_accuracy: 0.6967
# Epoch 68/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0928 - accuracy: 0.9771 - val_loss: 1.3560 - val_accuracy: 0.7233
# Epoch 69/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0831 - accuracy: 0.9729 - val_loss: 1.3142 - val_accuracy: 0.7067
# Epoch 70/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0775 - accuracy: 0.9771 - val_loss: 1.2830 - val_accuracy: 0.7200
# Epoch 71/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0981 - accuracy: 0.9714 - val_loss: 1.2059 - val_accuracy: 0.7333
# Epoch 72/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0734 - accuracy: 0.9800 - val_loss: 1.1070 - val_accuracy: 0.7400
# Epoch 73/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0847 - accuracy: 0.9757 - val_loss: 1.0524 - val_accuracy: 0.7500
# Epoch 74/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0913 - accuracy: 0.9729 - val_loss: 1.1584 - val_accuracy: 0.7133
# Epoch 75/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0935 - accuracy: 0.9714 - val_loss: 1.2355 - val_accuracy: 0.7200
# Epoch 76/100
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0666 - accuracy: 0.9814 - val_loss: 1.0697 - val_accuracy: 0.7467
# Epoch 77/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0587 - accuracy: 0.9914 - val_loss: 1.0036 - val_accuracy: 0.7733
# Epoch 78/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0639 - accuracy: 0.9829 - val_loss: 1.1659 - val_accuracy: 0.7367
# Epoch 79/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0599 - accuracy: 0.9886 - val_loss: 1.0173 - val_accuracy: 0.7433
# Epoch 80/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0526 - accuracy: 0.9857 - val_loss: 0.9698 - val_accuracy: 0.7800
# Epoch 81/100
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0720 - accuracy: 0.9757 - val_loss: 1.0335 - val_accuracy: 0.7467
# Epoch 82/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0528 - accuracy: 0.9857 - val_loss: 1.1667 - val_accuracy: 0.7333
# Epoch 83/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1095 - accuracy: 0.9614 - val_loss: 1.3102 - val_accuracy: 0.7100
# Epoch 84/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0814 - accuracy: 0.9771 - val_loss: 1.2468 - val_accuracy: 0.7200
# Epoch 85/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1052 - accuracy: 0.9643 - val_loss: 1.2676 - val_accuracy: 0.6800
# Epoch 86/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0977 - accuracy: 0.9714 - val_loss: 1.2909 - val_accuracy: 0.6967
# Epoch 87/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1012 - accuracy: 0.9686 - val_loss: 1.0871 - val_accuracy: 0.7400
# Epoch 88/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1101 - accuracy: 0.9614 - val_loss: 1.0910 - val_accuracy: 0.7400
# Epoch 89/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0621 - accuracy: 0.9886 - val_loss: 1.1108 - val_accuracy: 0.7467
# Epoch 90/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 0.9757 - val_loss: 1.1631 - val_accuracy: 0.7367
# Epoch 91/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0742 - accuracy: 0.9757 - val_loss: 1.2727 - val_accuracy: 0.7633
# Epoch 92/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0630 - accuracy: 0.9800 - val_loss: 1.2425 - val_accuracy: 0.7233
# Epoch 93/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0927 - accuracy: 0.9571 - val_loss: 1.2821 - val_accuracy: 0.7067
# Epoch 94/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1265 - accuracy: 0.9571 - val_loss: 1.3191 - val_accuracy: 0.7267
# Epoch 95/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0716 - accuracy: 0.9771 - val_loss: 1.3606 - val_accuracy: 0.7033
# Epoch 96/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0949 - accuracy: 0.9643 - val_loss: 1.0855 - val_accuracy: 0.7567
# Epoch 97/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0514 - accuracy: 0.9900 - val_loss: 1.0714 - val_accuracy: 0.7433
# Epoch 98/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0542 - accuracy: 0.9814 - val_loss: 1.1086 - val_accuracy: 0.7500
# Epoch 99/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0403 - accuracy: 0.9929 - val_loss: 1.1574 - val_accuracy: 0.7333
# Epoch 100/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0404 - accuracy: 0.9900 - val_loss: 1.1492 - val_accuracy: 0.7567

# %%
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1492 - accuracy: 0.7567
# Test accuracy: 0.7566666603088379

# %%
fig, axs = plt.subplots(2,figsize=(10,10))

# accuracy
axs[0].plot(hist.history["accuracy"], label="train")
axs[0].plot(hist.history["val_accuracy"], label="test")
axs[0].set_ylabel("Accuracy")
axs[0].legend()
axs[0].set_title("Accuracy")

# Error
axs[1].plot(hist.history["loss"], label="train")
axs[1].plot(hist.history["val_loss"], label="test")
axs[1].set_ylabel("Error")
axs[1].legend()
axs[1].set_title("Error")

plt.show()
